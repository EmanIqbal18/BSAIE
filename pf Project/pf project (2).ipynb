# %% [markdown]
# github link:
# https://github.com/EmanIqbal18/BSAIE

# %%
import pandas as pd

# %% [markdown]
# ### **How to Load the dataset:**

# %%
pd.read_csv("E project.csv")
# Out:
#       Review #           Brand  \
# 0       2580.0       New Touch
# 1       2579.0        Just Way
# 2       2578.0             NaN
# 3       2577.0         Wei Lih
# 4       2576.0  Ching's Secret
# ...        ...             ...
# 2575       5.0           Vifon
# 2576       4.0         Wai Wai
# 2577       3.0             NaN
# 2578       2.0         Wai Wai
# 2579       1.0        Westbrae
#
#                                                 Variety Style   Country Stars  \
# 0                             T's Restaurant Tantanmen    Cup     Japan  3.75
# 1     Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack    Taiwan     1
# 2                         Cup Noodles Chicken Vegetable   Cup       USA   NaN
# 3                         GGE Ramen Snack Tomato Flavor  Pack    Taiwan  2.75
# 4                                       Singapore Curry  Pack     India  3.75
# ...                                                 ...   ...       ...   ...
# ...

# %%
df = pd.read_csv("E project.csv")

# %%
df.head()
# Out:
#    Review #           Brand  \
# 0    2580.0       New Touch
# 1    2579.0        Just Way
# 2    2578.0             NaN
# 3    2577.0         Wei Lih
# 4    2576.0  Ching's Secret
#
#                                              Variety Style Country Stars  \
# 0                          T's Restaurant Tantanmen    Cup   Japan  3.75
# 1  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack  Taiwan     1
# 2                      Cup Noodles Chicken Vegetable   Cup     USA   NaN
# 3                      GGE Ramen Snack Tomato Flavor  Pack  Taiwan  2.75
# 4                                    Singapore Curry  Pack   India  3.75
#
#   Top Ten
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
df.tail()
# Out:
#       Review #     Brand                                            Variety  \
# 2575       5.0     Vifon  Hu Tiu Nam Vang ["Phnom Penh" style] Asian Sty...
# 2576       4.0   Wai Wai                     Oriental Style Instant Noodles
# 2577       3.0       NaN                                     Tom Yum Shrimp
# 2578       2.0   Wai Wai                               Tom Yum Chili Flavor
# 2579       1.0  Westbrae                                         Miso Ramen
#
#      Style   Country Stars Top Ten
# 2575   NaN   Vietnam   3.5     NaN
# 2576  Pack  Thailand     1     NaN
# 2577  Pack  Thailand     2     NaN
# 2578  Pack  Thailand   NaN     NaN
# 2579  Pack       USA   0.5     NaN

# %%
df.shape
# Out:
# (2580, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2580 entries, 0 to 2579
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Review #  2346 non-null   float64
#  1   Brand     2306 non-null   object
#  2   Variety   2318 non-null   object
#  3   Style     2346 non-null   object
#  4   Country   2305 non-null   object
#  5   Stars     2321 non-null   object
#  6   Top Ten   33 non-null     object
# dtypes: float64(1), object(6)
# memory usage: 141.2+ KB

# %%
df.describe(include="all")
# Out:
#            Review #   Brand Variety Style Country Stars Top Ten
# count   2346.000000    2306    2318  2346    2305  2321      33
# unique          NaN     341    2175     7      38    40      30
# top             NaN  Nissin    Beef  Pack   Japan     4      \n
# freq            NaN     335       7  1385     315   360       4
# mean    1292.056692     NaN     NaN   NaN     NaN   NaN     NaN
# std      743.969451     NaN     NaN   NaN     NaN   NaN     NaN
# min        1.000000     NaN     NaN   NaN     NaN   NaN     NaN
# 25%      644.500000     NaN     NaN   NaN     NaN   NaN     NaN
# 50%     1302.500000     NaN     NaN   NaN     NaN   NaN     NaN
# 75%     1937.750000     NaN     NaN   NaN     NaN   NaN     NaN
# max     2580.000000     NaN     NaN   NaN     NaN   NaN     NaN

# %% [markdown]
# ### **How to Clean the Dataset:**

# %%
df.isnull()
# Out:
#       Review #  Brand  Variety  Style  Country  Stars  Top Ten
# 0        False  False    False  False    False  False     True
# 1        False  False    False  False    False  False     True
# 2        False   True    False  False    False   True     True
# 3        False  False    False  False    False  False     True
# 4        False  False    False  False    False  False     True
# ...        ...    ...      ...    ...      ...    ...      ...
# 2575     False  False    False   True    False  False     True
# 2576     False  False    False  False    False  False     True
# 2577     False   True    False  False    False  False     True
# 2578     False  False    False  False    False   True     True
# 2579     False  False    False  False    False  False     True
#
# [2580 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# Review #     234
# Brand        274
# Variety      262
# Style        234
# Country      275
# Stars        259
# Top Ten     2547
# dtype: int64

# %%
df.columns
# Out:
# Index(['Review #', 'Brand', 'Variety', 'Style', 'Country', 'Stars', 'Top Ten'], dtype='object')

# %%
df.rename(columns={"Review #": "Review_no.","Style": "Packaging style", "Country": "Countries","Top Ten": "Top_10"})
# Out:
#       Review_no.           Brand  \
# 0         2580.0       New Touch
# 1         2579.0        Just Way
# 2         2578.0             NaN
# 3         2577.0         Wei Lih
# 4         2576.0  Ching's Secret
# ...          ...             ...
# 2575         5.0           Vifon
# 2576         4.0         Wai Wai
# 2577         3.0             NaN
# 2578         2.0         Wai Wai
# 2579         1.0        Westbrae
#
#                                                 Variety Packaging style  \
# 0                             T's Restaurant Tantanmen              Cup
# 1     Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...            Pack
# 2                         Cup Noodles Chicken Vegetable             Cup
# 3                         GGE Ramen Snack Tomato Flavor            Pack
# 4                                       Singapore Curry            Pack
# ...                                                 ...             ...
# ...

# %%
df.dropna()
# Out:
#       Review #             Brand  \
# 752     1828.0     Tseng Noodles
# 942     1638.0  A-Sha Dry Noodle
# 963     1617.0           MyKuali
# 1072    1508.0             Mamee
# 1080    1500.0           MyKuali
# 1109    1471.0              Mama
# 1272    1308.0          Nongshim
# 1278    1302.0              Mama
# 1382    1198.0     Samyang Foods
# 1397    1183.0             Paldo
# 1493    1087.0           MyKuali
# 1588     992.0       Prima Taste
# 1589     991.0       Prima Taste
# 1646     934.0          Nongshim
# 1670     910.0             Paldo
# 1846     734.0           Indomie
# 2188     392.0            Nissin
# 2475     105.0           Indomie
# 2533      47.0           Indomie
#
#                                                 Variety Style      Country  \
# 752                Scallion With Sichuan Pepper  Flavor  Pack       Taiwan
# 942   Veggie Noodle Tomato Noodle With Vine Ripened ...  Pack       Taiwan
# ...

# %%
df.fillna(10)
# Out:
#       Review #           Brand  \
# 0       2580.0       New Touch
# 1       2579.0        Just Way
# 2       2578.0              10
# 3       2577.0         Wei Lih
# 4       2576.0  Ching's Secret
# ...        ...             ...
# 2575       5.0           Vifon
# 2576       4.0         Wai Wai
# 2577       3.0              10
# 2578       2.0         Wai Wai
# 2579       1.0        Westbrae
#
#                                                 Variety Style   Country Stars  \
# 0                             T's Restaurant Tantanmen    Cup     Japan  3.75
# 1     Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack    Taiwan     1
# 2                         Cup Noodles Chicken Vegetable   Cup       USA    10
# 3                         GGE Ramen Snack Tomato Flavor  Pack    Taiwan  2.75
# 4                                       Singapore Curry  Pack     India  3.75
# ...                                                 ...   ...       ...   ...
# ...

# %%
df['Brand'].fillna(15)
df['Brand']
# Out:
# 0            New Touch
# 1             Just Way
# 2                  NaN
# 3              Wei Lih
# 4       Ching's Secret
#              ...
# 2575             Vifon
# 2576           Wai Wai
# 2577               NaN
# 2578           Wai Wai
# 2579          Westbrae
# Name: Brand, Length: 2580, dtype: object

# %%
df.drop(["Top Ten"],axis=1,inplace=True)
df
# Out:
#       Review #           Brand  \
# 0       2580.0       New Touch
# 1       2579.0        Just Way
# 2       2578.0             NaN
# 3       2577.0         Wei Lih
# 4       2576.0  Ching's Secret
# ...        ...             ...
# 2575       5.0           Vifon
# 2576       4.0         Wai Wai
# 2577       3.0             NaN
# 2578       2.0         Wai Wai
# 2579       1.0        Westbrae
#
#                                                 Variety Style   Country Stars
# 0                             T's Restaurant Tantanmen    Cup     Japan  3.75
# 1     Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack    Taiwan     1
# 2                         Cup Noodles Chicken Vegetable   Cup       USA   NaN
# 3                         GGE Ramen Snack Tomato Flavor  Pack    Taiwan  2.75
# 4                                       Singapore Curry  Pack     India  3.75
# ...                                                 ...   ...       ...   ...
# ...

# %%
df["Review no."] = df["Review #"].fillna(df["Review #"].mean())
df
# Out:
#       Review #           Brand  \
# 0       2580.0       New Touch
# 1       2579.0        Just Way
# 2       2578.0             NaN
# 3       2577.0         Wei Lih
# 4       2576.0  Ching's Secret
# ...        ...             ...
# 2575       5.0           Vifon
# 2576       4.0         Wai Wai
# 2577       3.0             NaN
# 2578       2.0         Wai Wai
# 2579       1.0        Westbrae
#
#                                                 Variety Style   Country Stars  \
# 0                             T's Restaurant Tantanmen    Cup     Japan  3.75
# 1     Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack    Taiwan     1
# 2                         Cup Noodles Chicken Vegetable   Cup       USA   NaN
# 3                         GGE Ramen Snack Tomato Flavor  Pack    Taiwan  2.75
# 4                                       Singapore Curry  Pack     India  3.75
# ...                                                 ...   ...       ...   ...
# ...

# %% [markdown]
# ### **How to duplicate Data**

# %%
df.duplicated
# Out:
# <bound method DataFrame.duplicated of       Review #           Brand  \
# 0       2580.0       New Touch
# 1       2579.0        Just Way
# 2       2578.0             NaN
# 3       2577.0         Wei Lih
# 4       2576.0  Ching's Secret
# ...        ...             ...
# 2575       5.0           Vifon
# 2576       4.0         Wai Wai
# 2577       3.0             NaN
# 2578       2.0         Wai Wai
# 2579       1.0        Westbrae
#
#                                                 Variety Style   Country Stars  \
# 0                             T's Restaurant Tantanmen    Cup     Japan  3.75
# 1     Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack    Taiwan     1
# 2                         Cup Noodles Chicken Vegetable   Cup       USA   NaN
# 3                         GGE Ramen Snack Tomato Flavor  Pack    Taiwan  2.75
# 4                                       Singapore Curry  Pack     India  3.75
# ...

# %%
df.drop_duplicates
# Out:
# <bound method DataFrame.drop_duplicates of       Review #           Brand  \
# 0       2580.0       New Touch
# 1       2579.0        Just Way
# 2       2578.0             NaN
# 3       2577.0         Wei Lih
# 4       2576.0  Ching's Secret
# ...        ...             ...
# 2575       5.0           Vifon
# 2576       4.0         Wai Wai
# 2577       3.0             NaN
# 2578       2.0         Wai Wai
# 2579       1.0        Westbrae
#
#                                                 Variety Style   Country Stars  \
# 0                             T's Restaurant Tantanmen    Cup     Japan  3.75
# 1     Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack    Taiwan     1
# 2                         Cup Noodles Chicken Vegetable   Cup       USA   NaN
# 3                         GGE Ramen Snack Tomato Flavor  Pack    Taiwan  2.75
# 4                                       Singapore Curry  Pack     India  3.75
# ...

# %% [markdown]
# ### **How to change Data types**

# %%
df['Review #'] = df['Review #'].astype(bool)
df.dtypes
# Out:
# Review #         bool
# Brand          object
# Variety        object
# Style          object
# Country        object
# Stars          object
# Review no.    float64
# dtype: object

# %% [markdown]
# ### **How to add new coloumn**

# %%
df["new_Top10"]=df["Review #"].mean()
df
# Out:
#       Review #           Brand  \
# 0         True       New Touch
# 1         True        Just Way
# 2         True             NaN
# 3         True         Wei Lih
# 4         True  Ching's Secret
# ...        ...             ...
# 2575      True           Vifon
# 2576      True         Wai Wai
# 2577      True             NaN
# 2578      True         Wai Wai
# 2579      True        Westbrae
#
#                                                 Variety Style   Country Stars  \
# 0                             T's Restaurant Tantanmen    Cup     Japan  3.75
# 1     Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack    Taiwan     1
# 2                         Cup Noodles Chicken Vegetable   Cup       USA   NaN
# 3                         GGE Ramen Snack Tomato Flavor  Pack    Taiwan  2.75
# 4                                       Singapore Curry  Pack     India  3.75
# ...                                                 ...   ...       ...   ...
# ...

# %% [markdown]
# ### **How to Remove coloumn**

# %%
df.drop(columns=["new_Top10"], inplace=True)
df
# Out:
#       Review #           Brand  \
# 0         True       New Touch
# 1         True        Just Way
# 2         True             NaN
# 3         True         Wei Lih
# 4         True  Ching's Secret
# ...        ...             ...
# 2575      True           Vifon
# 2576      True         Wai Wai
# 2577      True             NaN
# 2578      True         Wai Wai
# 2579      True        Westbrae
#
#                                                 Variety Style   Country Stars  \
# 0                             T's Restaurant Tantanmen    Cup     Japan  3.75
# 1     Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack    Taiwan     1
# 2                         Cup Noodles Chicken Vegetable   Cup       USA   NaN
# 3                         GGE Ramen Snack Tomato Flavor  Pack    Taiwan  2.75
# 4                                       Singapore Curry  Pack     India  3.75
# ...                                                 ...   ...       ...   ...
# ...

# %% [markdown]
# ### **How to Add new Row**

# %%
a = pd.DataFrame({'Review #':2581,
                  'Brand':'indomie',
                    'Variety':'pack'},
                     index=[0])
a
df=pd.concat([a,df])
df
# Out:
#       Review #      Brand                                            Variety  \
# 0         2581    indomie                                               pack
# 0            1  New Touch                          T's Restaurant Tantanmen
# 1            1   Just Way  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...
# 2            1        NaN                      Cup Noodles Chicken Vegetable
# 3            1    Wei Lih                      GGE Ramen Snack Tomato Flavor
# ...        ...        ...                                                ...
# 2575         1      Vifon  Hu Tiu Nam Vang ["Phnom Penh" style] Asian Sty...
# 2576         1    Wai Wai                     Oriental Style Instant Noodles
# 2577         1        NaN                                     Tom Yum Shrimp
# 2578         1    Wai Wai                               Tom Yum Chili Flavor
# 2579         1   Westbrae                                         Miso Ramen
#
#      Style   Country Stars  Review no.
# ...

# %% [markdown]
# ### **How to remove Row**

# %%
df. drop(0,inplace=True)
df
# Out:
#       Review #           Brand  \
# 1            1        Just Way
# 2            1             NaN
# 3            1         Wei Lih
# 4            1  Ching's Secret
# 5            1   Samyang Foods
# ...        ...             ...
# 2575         1           Vifon
# 2576         1         Wai Wai
# 2577         1             NaN
# 2578         1         Wai Wai
# 2579         1        Westbrae
#
#                                                 Variety Style      Country  \
# 1     Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack       Taiwan
# 2                         Cup Noodles Chicken Vegetable   Cup          USA
# 3                         GGE Ramen Snack Tomato Flavor  Pack       Taiwan
# 4                                       Singapore Curry  Pack        India
# 5                                Kimchi song Song Ramen  Pack  South Korea
# ...                                                 ...   ...          ...
# ...

# %% [markdown]
# ### **Specific or Particular Data**

# %%
df[7:9]
# Out:
#    Review # Brand                                Variety Style    Country  \
# 8         1   NaN               Hokkaido Soy Sauce Ramen  Pack        NaN
# 9         1  KOKA  The Original Spicy Stir-Fried Noodles  Pack  Singapore
#
#   Stars  Review no.
# 8  0.25      2572.0
# 9   NaN      2571.0

# %%
df[7:9:6]
# Out:
#    Review # Brand                   Variety Style Country Stars  Review no.
# 8         1   NaN  Hokkaido Soy Sauce Ramen  Pack     NaN  0.25      2572.0

# %%
df[['Brand']][22:33]
# Out:
#                Brand
# 23          Yamachan
# 24    Ching's Secret
# 25               NaN
# 26           Yum-Mie
# 27            Nissin
# 28           MyKuali
# 29              KOKA
# 30     Samyang Foods
# 31            Nissin
# 32            Ottogi
# 33  Sichuan Guangyou

# %% [markdown]
# ### **Data Aggregation:**

# %%
df.agg({'Review #': ['sum', 'mean']})
# Out:
#       Review #
# sum     2579.0
# mean       1.0

# %%
df.groupby('Review #')

# %%
df["Style"].value_counts()
# Out:
# Style
# Pack    1385
# Bowl     441
# Cup      411
# Tray     100
# Box        6
# Can        1
# Bar        1
# Name: count, dtype: int64

# %% [markdown]
# ### **Data Filtering**

# %%
df.describe(include="all").iloc[[0,10]]
# Out:
#        Review # Brand Variety Style Country Stars  Review no.
# count    2579.0  2305    2317  2345    2304  2320      2579.0
# max         1.0   NaN     NaN   NaN     NaN   NaN      2579.0

# %%
df.describe(include="all").loc[["min","max"]]
# Out:
#      Review # Brand Variety Style Country Stars  Review no.
# min       1.0   NaN     NaN   NaN     NaN   NaN         1.0
# max       1.0   NaN     NaN   NaN     NaN   NaN      2579.0

# %% [markdown]
# ### **How to Make Flow charts:**

# %%
df['Style'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Style'>

# %%
df['Style'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df['Style'].value_counts().plot(kind='line')
# Out:
# <Axes: xlabel='Style'>

# %% [markdown]
# ### **Statistical Analysis:**

# %%
df['Review no.'].mean()
# Out:
# np.float64(1291.5572958451548)

# %%
df['Review no.'].median()
# Out:
# np.float64(1292.0566922421142)

# %%
df['Review no.'].mode()
# Out:
# 0    1292.056692
# Name: Review no., dtype: float64

# %%
df['Review no.'].min()
# Out:
# np.float64(1.0)

# %%
df['Review no.'].max()
# Out:
# np.float64(2579.0)

# %%
df['Review no.'].std()
# Out:
# np.float64(709.0996395417018)

# %%
df = pd.read_csv("E project.csv")
df.to_excel("E project.xlsx", sheet_name="E project")
